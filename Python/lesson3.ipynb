# %%
"""Основная терминология."""

# %% [markdown]
# Анаконда - это дистрибутив, который содержит в себе много инструментов, включая менеджер пакетов conda (пакеты для библиотеки Data science) Аналог - менеджера пакетов pip (это стандартный менеджер в Питоне)
# Таким образом, если не поставили conda, буду ставить через pip install package_name
# __init__.py  это файл загрузчик,где подключаются все зависимости, который подключается автоматически к модулю, когда интерпритатор видит ключевое слово импорт (два подчеркивания __init__ читается как дандер), такие файлы или методы являются магическими
# файл __init__.py нужен для инициализации пакета
# файл __init__.py нужен для разграничения пространства имен
# зависимости - это библиотеки, модуль или пакеты
# пакет - это набор модулей
# модуль - это файл с расширением .py
# инициализациЯ пакета - это указание интерпритатору дирректорию где искать пакеты
# через точку мы обращаемся не только к имени функции, могу обратиться к имени модуля,
# через точку я получаю доступ к пространству имен
# при обращении к пакету или модулю

# %% [markdown]
# # https://docs.sympy.org/latest/tutorials/intro-tutorial/gotchas.html#symbols
